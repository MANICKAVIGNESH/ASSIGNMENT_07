# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## read data from csv file

# %%
red_wine_data_set = pd.read_csv("/content/sample_data/STUDY/winequality-red.csv")

# %% [markdown]
# ## get information of collected data frame
#
# ### The important is to check all value presented or not

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
red_wine_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_wine_data_set.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %% [markdown]
# # To finding missing values

# %%
red_wine_data_set.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## view overall dataframe

# %%
red_wine_data_set
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## To see how many different values inside 1 columns

# %%
quality_counts = red_wine_data_set['quality'].value_counts().reset_index()
quality_counts.columns = ['quality', 'Count']
# Creating a pie chart
fig = px.pie(quality_counts, values='Count', names='quality', title='No. of different score values available in quality column')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
quality_counts
# Out:
#    quality  Count
# 0        5    681
# 1        6    638
# 2        7    199
# 3        4     53
# 4        8     18
# 5        3     10

# %% [markdown]
# ### To see all unique values inside the columns

# %%
quality_values = red_wine_data_set['quality']
arr1 = []
for i in quality_values:
  if i not in arr1:
    arr1.append(i)
arr1.sort()
print(arr1)
# Out:
# [3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## To see box plots for all columns

# %%
sns.boxplot(x = ['residual sugar'])
# Out:
# <Axes: >

# %% [markdown]
# # TO show Heat map for Overall Data frame
# ## for finding cocorrelation between all the numerical columns

# %%
sns.heatmap(red_wine_data_set.corr(),cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'red_wine_data_set' is your DataFrame containing numerical columns
# Compute correlation matrix
correlation_matrix = red_wine_data_set.corr()

# Plot heatmap with custom colormap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='RdYlBu', annot=True, center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # To visualizing the 2 columns values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract 'alcohol' and 'quality' columns
alcohol = red_wine_data_set['alcohol']
quality = red_wine_data_set['quality']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(alcohol, quality, color='blue', alpha=0.5)

# Add labels and title
plt.title('Alcohol Content vs Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')

# Show plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract 'alcohol' and 'quality' columns
alcohol = red_wine_data_set['fixed acidity']
quality = red_wine_data_set['citric acid']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(alcohol, quality, color='blue', alpha=0.5)

# Add labels and title
plt.title('fixed acidity vs citric acid ')
plt.xlabel('fixed acidity')
plt.ylabel('citric acid')

# Show plot
plt.grid(True)
plt.show()

# %% [markdown]
# # It sum the 5 columns and compare to 1 column then show coorelation between values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# Load the dataset
data = red_wine_data_set

# Calculate the sum of citric acid and fixed acidity
data['sum_acidity'] = data['citric acid'] + data['fixed acidity'] + data['volatile acidity'] + data['residual sugar'] + data['chlorides'] + data['total sulfur dioxide'] + data['density'] + data['pH'] + data['sulphates'] + data['alcohol']

# Calculate correlation
correlation = data['quality'].corr(data['sum_acidity'])

# Plot bar chart using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(data['quality'], data['sum_acidity'], color='skyblue')
plt.xlabel('Quality')
plt.ylabel('Sum of Acidity')
plt.title(f'Correlation between Quality and Sum of Acidity\nCorrelation Coefficient: {correlation:.2f}')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# Load the dataset
data = red_wine_data_set

# Calculate the sum of citric acid and fixed acidity
data['quality_rev'] = quality_score = [1 if i >= 6.5 else 0 for i in data['quality']]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# Load the dataset
data = red_wine_data_set
# Calculate correlation
correlation = data['quality'].corr(data['total_acidity'])

# Plot bar chart using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(data['quality'], data['total_acidity'], color='skyblue')
plt.xlabel('Quality')
plt.ylabel('total_acidity')
plt.title(f'Correlation between Quality and total_acidity\nCorrelation Coefficient: {correlation:.2f}')
plt.show()

# %%
a = red_wine_data_set['quality']

quality_score = []
for i in a:
  if i >= 6.5:
    quality_score.append("good")
  else:
    quality_score.append("bad")
print(quality_score)
a['quality_score'] = quality_score
# Out:
# ['bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad', 'bad
# ...

# %%
red_wine_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  sum_acidity           1599 non-null   float64
#  13  quality_rev           1599 non-null   int64
# dtypes: float64(12), int64(2)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
df = red_wine_data_set
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  sum_acidity  quality_rev
# ...

# %%
X = df[['sum_acidity','quality_rev']].values
y = df["quality_rev"]


model= DecisionTreeClassifier(criterion="gini", max_depth = 10)
model.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predicting on the training data
y_pred = model.predict(X)

# Evaluate accuracy
accuracy = accuracy_score(y, y_pred)
print("Accuracy:", accuracy)

# Generate classification report
print("Classification Report:")
print(classification_report(y, y_pred))

# Generate confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1382
#            1       1.00      1.00      1.00       217
#
#     accuracy                           1.00      1599
#    macro avg       1.00      1.00      1.00      1599
# weighted avg       1.00      1.00      1.00      1599
#
# Confusion Matrix:
# [[1382    0]
#  [   0  217]]

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(model, filled=True, feature_names=["sum_acidity", "quality_rev"], class_names=["Poor", "Normal", "Excellent"])
plt.show()

# %% [markdown]
# split x

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Step 1: Load Data
# Assuming df is your DataFrame containing the dataset

# Step 2: Preprocess Data
# Assuming X contains features and y contains the target variable
X = df[['sum_acidity']]
y = df['quality_rev']

# Step 3: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Step 4: Train Decision Tree Regressor
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train, y_train)

# Step 5: Make Predictions
# Predict target values for the training set
y_pred_train = regressor.predict(X_train)
# Predict target values for the test set
y_pred_test = regressor.predict(X_test)

# Convert predictions to binary based on the threshold
y_pred_train_binary = (y_pred_train > 1).astype(int)
y_pred_test_binary = (y_pred_test > 1).astype(int)

# Step 6: Evaluate the model using accuracy score
train_accuracy = accuracy_score(y_train, y_pred_train_binary)
test_accuracy = accuracy_score(y_test, y_pred_test_binary)

print(f'Train Accuracy: {train_accuracy}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Train Accuracy: 0.8632193494578816
# Test Accuracy: 0.8675

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Assuming y_test and y_pred_test are defined as the true target values and predicted values respectively

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred_test)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred_test)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 0.1961111111111111
# Root Mean Squared Error (RMSE): 0.44284434185288074
# Mean Absolute Error (MAE): 0.19666666666666666

# %%
quality_counts = red_wine_data_set['free sulfur dioxide'].value_counts().reset_index()
quality_counts.columns = ['free sulfur dioxide', 'Count']
# Creating a pie chart
fig = px.pie(quality_counts, values='Count', names='free sulfur dioxide', title='No. of different score values available in free sulfur dioxide column')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
